# %%
# !pip install transformers
# !pip install accelerate
# TODO: check lr scheduler
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting accelerate
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score as kappa
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import GPT2Tokenizer, GPT2Model
from matplotlib import pyplot as plt
from tqdm.auto import tqdm
import os
import time
import pathlib

# log folder to save log files
log_folder = '/content/drive/MyDrive/asap/'

# target column
target_column = "score"

# hyper parameters
hp = {
    "base_model": "gpt2",
    "lr": 1e-4,
    "num_epochs": 35,
    "batch_size": 2,
    "use_amp": True,
    "mixed_precision": "fp16",
}

# %% [markdown]
# # Prepare ASAP Dataset

# %%
# Original kaggle training set
kaggle_dataset  = pd.read_csv('/content/drive/MyDrive/asap-aes/training_set_rel3.tsv', sep='\t', encoding = "ISO-8859-1")

# Smaller training set used for this project
dataset_df = pd.DataFrame(
  {
    'essay_id' : kaggle_dataset['essay_id'],
    'essay_set' : kaggle_dataset['essay_set'],
    'essay' : kaggle_dataset['essay'],
    'rater1' : kaggle_dataset['rater1_domain1'],
    'rater2' : kaggle_dataset['rater2_domain1'],
    'score' : kaggle_dataset['domain2_score']
  })
dataset_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1  rater2  score
# 0       4       4    NaN
# 1       5       4    NaN
# 2       4       3    NaN
# 3       5       5    NaN
# 4       4       4    NaN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Use essay_set=2 for classification

# %%
essay_df = dataset_df[dataset_df['essay_set'] == 2].copy()
essay_df.shape

# essay_df = dataset_df.loc[(dataset_df['essay_set'] == 3) | (dataset_df['essay_set'] == 4) | (dataset_df['essay_set'] == 5) | (dataset_df['essay_set'] == 6)].copy()
# essay_df.shape
# Out:
# (1800, 6)

# %%
import numpy as np
# Use minimum score
rater_1 = essay_df["rater1"].to_numpy()
rater_2 = essay_df["rater2"].to_numpy()

min_score = np.minimum(rater_1, rater_2)
max_score = np.maximum(rater_1, rater_2)

essay_df['min_score'] = min_score
essay_df['max_score'] = max_score

# %%
essay_df['score'].value_counts()
# Out:
# 4.0    850
# 3.0    730
# 2.0    191
# 1.0     29
# Name: score, dtype: int64

# %%
essay_df['score'] = essay_df['score'].astype(int)

# %%
essay_df[target_column] - essay_df[target_column].min()
# Out:
# 1783    3
# 1784    0
# 1785    2
# 1786    3
# 1787    3
#        ..
# 3578    2
# 3579    2
# 3580    1
# 3581    3
# 3582    1
# Name: score, Length: 1800, dtype: int64

# %%
from sklearn.model_selection import train_test_split

essay_df['target_score'] = essay_df[target_column] - essay_df[target_column].min()

X, y = essay_df['essay'].to_list(), essay_df['target_score'].to_numpy()
num_labels = essay_df[target_column].unique().size

# 60 / 40 train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42) # stratify=y, this paramter will not work if any class has number of examples lower than 2

# split test to half to get 60 / 20 / 20 split

X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.50, random_state=42) # stratify=y_test

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# a torch dataset implementation for ASAP dataset
class EssayDataset(Dataset):
    def __init__(self, essays, targets, tokenizer):
        self.essays = essays
        self.targets = targets
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.essays)

    def __getitem__(self, idx):
        text = str(self.essays[idx])
        encoded_input = tokenizer(text, truncation=True, return_tensors='pt').to(device)

        return encoded_input['input_ids'].squeeze(), encoded_input['attention_mask'].squeeze(), self.targets[idx]

# %%
# collater function to pad tokens
def collate_fn(batch):
    PAD_TOKEN_ID = 50256 # Use tokenizer.pad_token_id to check
    input_ids_list, attention_mask_list, targets = [], [], []

    for input_ids, attention_mask, target in batch:
        input_ids_list.append(input_ids)
        attention_mask_list.append(attention_mask)
        targets.append(target)

    # Pad the batch to the maximum sequence length within that batch using the tokenizer's pad token
    max_length = max(len(ids) for ids in input_ids_list)
    padded_input_ids = []
    padded_attention_mask = []

    for input_ids, attention_mask in zip(input_ids_list, attention_mask_list):
        pad_length = max_length - len(input_ids)
        padded_input_ids.append(torch.cat([input_ids, torch.tensor([PAD_TOKEN_ID] * pad_length, device=device, dtype=torch.long)]))
        # add zeros to attention mask for padds
        padded_attention_mask.append(torch.cat([attention_mask, torch.zeros(pad_length, dtype=torch.long, device=device)]))

    return torch.stack(padded_input_ids), torch.stack(padded_attention_mask), torch.tensor(targets)

# %%
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained(hp['base_model'])
tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %%
from transformers import GPT2ForSequenceClassification

class ClassifierLayer(torch.nn.Module):

  def __init__(self, input_size, output_size, bias=False):
    super(ClassifierLayer, self).__init__()

    self.dropout = torch.nn.Dropout(0.1)
    self.linear = torch.nn.Linear(input_size, output_size, bias=bias)

  def forward(self, x):
    inputs = self.dropout(x)
    return self.linear(inputs)

class GPT2Classification(GPT2ForSequenceClassification):
    def __init__(self, config):
        super().__init__(config)
        self.score = ClassifierLayer(config.n_embd, self.num_labels, bias=False)

        self.post_init()

# %%
from accelerate import Accelerator

# use fp16 mixed precision to improve training speed
accelerator = Accelerator(mixed_precision=hp['mixed_precision']) # fp16
device = accelerator.device

model = GPT2Classification.from_pretrained(hp['base_model'], num_labels=num_labels)
#model = GPT2ForSequenceClassification.from_pretrained(hp['base_model'], num_labels=num_labels)
model.to(device)
tokenizer.pad_token_id = tokenizer.eos_token_id
# fix model padding token id
model.config.pad_token_id = model.config.eos_token_id
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Some weights of GPT2Classification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.linear.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sklearn.metrics import classification_report
# train loop

def train_loop(model, train_loader, val_loader, loss_fct, optimizer, lr_scheduler, progress_bar, log_file_handler, logging_step=1, use_amp=False):
    samples = 0.
    cumulative_loss = 0.

    # set model to train mode
    model.train()

    for step, (inputs, attention_masks, targets) in enumerate(train_loader):
        targets = targets.reshape(-1, 1).to(device)
        attention_masks = attention_masks.to(device)
        outputs = model(inputs, attention_mask=attention_masks)
        loss = loss_fct(outputs["logits"].view(-1, model.num_labels), targets.view(-1))
        accelerator.backward(loss)
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)

        samples += inputs.shape[0]
        cumulative_loss += loss.item()

        if step % logging_step == 0:
            # calculate cls_report on test set

            with torch.no_grad():
                test_loss, test_preds, cls_report = test_loop(model, val_loader, loss_fct, use_amp=use_amp)
            model.train()
            log_str = "Step: {:<6} \t Train loss: {:<6.4f} \t Validation loss: {:<6.4f}".format(step, (cumulative_loss/samples), test_loss)
            # Adding f1 accuracy recall prec metics
            log_str += "\n" + cls_report
            print(log_str)
            log_file_handler.write(log_str + "\n")
            samples = 0
            cumulative_loss = 0

    return cumulative_loss/samples if samples != 0 else float("inf")

def test_loop(model, test_loader, loss_fct, use_amp=False, show_progression=False):
    samples = 0.
    cumulative_loss = 0.
    preds = []
    labels = []

    # set model to eval mode
    model.eval()

    loop_iterator = enumerate(tqdm(test_loader)) if show_progression else enumerate(test_loader)

    with torch.no_grad():
        for step, (inputs, attention_masks, targets) in loop_iterator:
            targets = targets.reshape(-1, 1).to(device)
            inputs = inputs.to(device)
            attention_masks = attention_masks.to(device)
            with torch.autocast(device_type='cuda', dtype=torch.float16):
                outputs = model(inputs, attention_mask=attention_masks)
            loss = loss_fct(outputs["logits"].view(-1, model.num_labels), targets.view(-1))

            samples += inputs.shape[0]
            cumulative_loss += loss.item()

            probs = outputs['logits'].softmax(-1) # probs
            predictions = probs.argmax(-1) # predicted classes

            labels.extend(targets.tolist())
            preds.extend(predictions.tolist())

        cls_report = classification_report(labels, preds, zero_division=0)

    return cumulative_loss/samples if samples != 0 else float("inf"), np.asarray(preds, dtype=np.float32), cls_report

# %%
from tqdm.auto  import tqdm
from transformers import get_scheduler
from torch.optim import AdamW
from sklearn.utils import class_weight

lr = hp['lr']
num_epochs = hp['num_epochs']
batch_size = hp['batch_size']
use_amp = hp['use_amp']

# create train data loader
train_dataset = EssayDataset(X_train, y_train, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
num_training_steps = num_epochs * len(train_loader)

# create test data loader
test_dataset = EssayDataset(X_test, y_test, tokenizer)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

# create val data loader
val_dataset = EssayDataset(X_val, y_val, tokenizer)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

# # get class weights
# class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
# class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

loss_fct = torch.nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=lr)
lr_scheduler = get_scheduler(
    name="linear", optimizer=optimizer,
    num_warmup_steps=0, num_training_steps=num_training_steps
)
scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

# use accelerator prepare

# removed val_loader from prepare command
model, optimizer, train_loader, test_loader, val_loader, lr_scheduler = accelerator.prepare(
    model, optimizer, train_loader, test_loader, val_loader, lr_scheduler
)

# %%
def open_log_file(log_folder, essay_df, model, label_column: str, hyper_parameters):
    # using time as a file name for logging

    timestr = time.strftime("%Y%m%d-%H%M%S")
    file_name = timestr + '.log'

    # check if folder exists, create if it isn't
    pathlib.Path(log_folder).mkdir(exist_ok=True, parents=True)

    # open file to log results
    log_file = os.path.join(log_folder, file_name)
    fp = open(log_file, "a")

    fp.write("Log time: " + timestr + "\n")
    fp.write("Essay classes: " + str(essay_df['essay_set'].unique()) + "\n")
    fp.write("Using score column: " + label_column + "\n")
    fp.write("Score distribution: " + "\n" + essay_df[label_column].value_counts().to_string() + "\n")

    fp.write("\n--- Model parameters:\n")
    fp.write(str(model))
    fp.write('\n')

    fp.write("\n--- Hyper parameters:\n")
    for k, v in hyper_parameters.items():
        fp.write(f" {k:<25}: {v}\n")

    fp.write('\n')
    fp.flush()
    return fp

# %%
# !nvidia-smi
# Out:
# Thu Dec 14 17:10:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    26W /  70W |   1199MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# Start logging to a file
fp = open_log_file(log_folder, essay_df, model, label_column=target_column, hyper_parameters=hp)

try:
    # Start training
    progress_bar = tqdm(range(num_training_steps))

    model.train()
    with accelerator.autocast():
        fp.write("Training logs: \n\n")
        for epoch in range(num_epochs):
            train_loss = train_loop(model, train_loader, val_loader, loss_fct, optimizer, lr_scheduler, progress_bar, fp, logging_step=len(train_loader)//3, use_amp=hp['use_amp'])
            with torch.no_grad():
                test_loss, test_preds, cls_report = test_loop(model, test_loader, loss_fct)
                log_string = "Epoch: {:<6}\t Test  loss: {:<6.4f}".format(epoch+1, test_loss)
                log_string += "\n" + cls_report
                print(log_string)
                fp.write(log_string + "\n")
finally:
    print("Log file closed.")
    fp.close()
# Out:
#   0%|          | 0/25200 [00:00<?, ?it/s]
# Step: 0      	 Train loss: 1.7827 	 Validation loss: 2.0124
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       1.00      0.01      0.03        78
#            3       0.45      1.00      0.62        80
#
#     accuracy                           0.45       180
#    macro avg       0.36      0.25      0.16       180
# weighted avg       0.63      0.45      0.29       180
#
# Step: 240    	 Train loss: 0.9288 	 Validation loss: 0.7054
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.17      0.01      0.02        78
#            3       0.43      0.94      0.59        80
#
#     accuracy                           0.42       180
#    macro avg       0.15      0.24      0.15       180
# weighted avg       0.26      0.42      0.27       180
#
# Step: 480    	 Train loss: 0.5792 	 Validation loss: 0.6153
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        78
#            3       0.43      0.94      0.59        80
#
#     accuracy                           0.42       180
#    macro avg       0.11      0.23      0.15       180
# weighted avg       0.19      0.42      0.26       180
#
# Epoch: 1     	 Test  loss: 0.6047
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        78
#            3       0.44      0.97      0.60        80
#
#     accuracy                           0.43       180
#    macro avg       0.11      0.24      0.15       180
# weighted avg       0.19      0.43      0.27       180
#
# Step: 0      	 Train loss: 0.7410 	 Validation loss: 0.6051
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        78
#            3       0.44      0.97      0.60        80
#
#     accuracy                           0.43       180
#    macro avg       0.11      0.24      0.15       180
# weighted avg       0.19      0.43      0.27       180
#
# Step: 240    	 Train loss: 0.5011 	 Validation loss: 0.6148
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        78
#            3       0.44      0.95      0.60        80
#
#     accuracy                           0.42       180
#    macro avg       0.11      0.24      0.15       180
# weighted avg       0.19      0.42      0.27       180
#
# Step: 480    	 Train loss: 0.4874 	 Validation loss: 0.6635
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        78
#            3       0.45      1.00      0.62        80
#
#     accuracy                           0.44       180
#    macro avg       0.11      0.25      0.16       180
# weighted avg       0.20      0.44      0.28       180
#
# Epoch: 2     	 Test  loss: 0.5884
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.33      0.04      0.07        78
#            3       0.46      0.97      0.62        80
#
#     accuracy                           0.45       180
#    macro avg       0.20      0.25      0.17       180
# weighted avg       0.35      0.45      0.31       180
#
# Step: 0      	 Train loss: 0.5868 	 Validation loss: 0.5979
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.33      0.04      0.07        78
#            3       0.46      0.97      0.62        80
#
#     accuracy                           0.45       180
#    macro avg       0.20      0.25      0.17       180
# weighted avg       0.35      0.45      0.31       180
#
# Step: 240    	 Train loss: 0.4438 	 Validation loss: 0.7452
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.25      0.01      0.02        78
#            3       0.45      1.00      0.62        80
#
#     accuracy                           0.45       180
#    macro avg       0.18      0.25      0.16       180
# weighted avg       0.31      0.45      0.29       180
#
# Step: 480    	 Train loss: 0.4041 	 Validation loss: 0.7570
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.33      0.03      0.05        78
#            3       0.46      1.00      0.63        80
#
#     accuracy                           0.46       180
#    macro avg       0.20      0.26      0.17       180
# weighted avg       0.35      0.46      0.30       180
#
# Epoch: 3     	 Test  loss: 0.6138
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.50      0.10      0.17        78
#            3       0.48      0.99      0.65        80
#
#     accuracy                           0.48       180
#    macro avg       0.25      0.27      0.20       180
# weighted avg       0.43      0.48      0.36       180
#
# Step: 0      	 Train loss: 0.2125 	 Validation loss: 0.6071
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        20
#            2       0.50      0.10      0.17        78
#            3       0.48      0.99      0.65        80
#
#     accuracy                           0.48       180
#    macro avg       0.25      0.27      0.20       180
# weighted avg       0.43      0.48      0.36       180
#
# Step: 240    	 Train loss: 0.3988 	 Validation loss: 0.7346
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.05      0.10        20
#            2       0.50      0.04      0.07        78
#            3       0.46      0.99      0.62        80
#
#     accuracy                           0.46       180
#    macro avg       0.49      0.27      0.20       180
# weighted avg       0.53      0.46      0.32       180
#
# Step: 480    	 Train loss: 0.3553 	 Validation loss: 0.7346
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.15      0.26        20
#            2       0.55      0.08      0.13        78
#            3       0.48      1.00      0.65        80
#
#     accuracy                           0.49       180
#    macro avg       0.51      0.31      0.26       180
# weighted avg       0.56      0.49      0.38       180
#
# Epoch: 4     	 Test  loss: 0.5479
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.15      0.26        20
#            2       0.67      0.26      0.37        78
#            3       0.52      0.96      0.68        80
#
#     accuracy                           0.56       180
#    macro avg       0.55      0.34      0.33       180
# weighted avg       0.63      0.56      0.49       180
#
# Step: 0      	 Train loss: 0.1368 	 Validation loss: 0.5489
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.15      0.26        20
#            2       0.67      0.26      0.37        78
#            3       0.52      0.96      0.68        80
#
#     accuracy                           0.56       180
#    macro avg       0.55      0.34      0.33       180
# weighted avg       0.63      0.56      0.49       180
#
# Step: 240    	 Train loss: 0.3142 	 Validation loss: 0.8562
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.10      0.18        20
#            2       0.60      0.08      0.14        78
#            3       0.48      1.00      0.65        80
#
#     accuracy                           0.49       180
#    macro avg       0.52      0.29      0.24       180
# weighted avg       0.58      0.49      0.37       180
#
# Step: 480    	 Train loss: 0.3060 	 Validation loss: 0.5792
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.15      0.26        20
#            2       0.67      0.31      0.42        78
#            3       0.54      0.95      0.69        80
#
#     accuracy                           0.57       180
#    macro avg       0.55      0.35      0.34       180
# weighted avg       0.64      0.57      0.52       180
#
# Epoch: 5     	 Test  loss: 0.7433
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.20      0.33        20
#            2       0.71      0.13      0.22        78
#            3       0.50      1.00      0.66        80
#
#     accuracy                           0.52       180
#    macro avg       0.55      0.33      0.30       180
# weighted avg       0.64      0.52      0.43       180
#
# Step: 0      	 Train loss: 0.2589 	 Validation loss: 0.7625
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.20      0.33        20
#            2       0.71      0.13      0.22        78
#            3       0.49      1.00      0.66        80
#
#     accuracy                           0.52       180
#    macro avg       0.55      0.33      0.30       180
# weighted avg       0.64      0.52      0.43       180
#
# Step: 240    	 Train loss: 0.2714 	 Validation loss: 0.7680
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.20      0.33        20
#            2       0.72      0.17      0.27        78
#            3       0.51      1.00      0.68        80
#
#     accuracy                           0.54       180
#    macro avg       0.56      0.34      0.32       180
# weighted avg       0.65      0.54      0.46       180
#
# Step: 480    	 Train loss: 0.2746 	 Validation loss: 0.7727
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.15      0.26        20
#            2       0.61      0.14      0.23        78
#            3       0.51      1.00      0.67        80
#
#     accuracy                           0.52       180
#    macro avg       0.53      0.32      0.29       180
# weighted avg       0.60      0.52      0.43       180
#
# Epoch: 6     	 Test  loss: 0.5926
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.73      0.40      0.52        20
#            2       0.73      0.28      0.41        78
#            3       0.56      0.96      0.71        80
#
#     accuracy                           0.59       180
#    macro avg       0.50      0.41      0.41       180
# weighted avg       0.65      0.59      0.55       180
#
# Step: 0      	 Train loss: 0.0391 	 Validation loss: 0.5759
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.73      0.40      0.52        20
#            2       0.71      0.28      0.40        78
#            3       0.55      0.95      0.70        80
#
#     accuracy                           0.59       180
#    macro avg       0.50      0.41      0.41       180
# weighted avg       0.63      0.59      0.54       180
#
# Step: 240    	 Train loss: 0.2075 	 Validation loss: 0.8283
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.78      0.35      0.48        20
#            2       0.69      0.14      0.23        78
#            3       0.52      1.00      0.68        80
#
#     accuracy                           0.54       180
#    macro avg       0.50      0.37      0.35       180
# weighted avg       0.62      0.54      0.46       180
#
# Step: 480    	 Train loss: 0.2291 	 Validation loss: 0.7179
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.25      0.40        20
#            2       0.76      0.28      0.41        78
#            3       0.54      0.99      0.70        80
#
#     accuracy                           0.59       180
#    macro avg       0.58      0.38      0.38       180
# weighted avg       0.68      0.59      0.53       180
#
# Epoch: 7     	 Test  loss: 0.6871
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.73      0.40      0.52        20
#            2       0.81      0.28      0.42        78
#            3       0.56      0.99      0.72        80
#
#     accuracy                           0.61       180
#    macro avg       0.53      0.42      0.41       180
# weighted avg       0.68      0.61      0.56       180
#
# Step: 0      	 Train loss: 0.0943 	 Validation loss: 0.6965
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.80      0.40      0.53        20
#            2       0.82      0.29      0.43        78
#            3       0.56      0.99      0.71        80
#
#     accuracy                           0.61       180
#    macro avg       0.55      0.42      0.42       180
# weighted avg       0.69      0.61      0.57       180
#
# Step: 240    	 Train loss: 0.1696 	 Validation loss: 0.7863
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.71      0.50      0.59        20
#            2       0.87      0.26      0.40        78
#            3       0.57      1.00      0.73        80
#
#     accuracy                           0.61       180
#    macro avg       0.54      0.44      0.43       180
# weighted avg       0.71      0.61      0.56       180
#
# Step: 480    	 Train loss: 0.1547 	 Validation loss: 1.0018
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.67      0.30      0.41        20
#            2       0.73      0.14      0.24        78
#            3       0.52      1.00      0.69        80
#
#     accuracy                           0.54       180
#    macro avg       0.48      0.36      0.33       180
# weighted avg       0.62      0.54      0.45       180
#
# Epoch: 8     	 Test  loss: 0.8609
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.75      0.30      0.43        20
#            2       0.79      0.24      0.37        78
#            3       0.55      1.00      0.71        80
#
#     accuracy                           0.58       180
#    macro avg       0.52      0.39      0.38       180
# weighted avg       0.67      0.58      0.52       180
#
# Step: 0      	 Train loss: 0.1036 	 Validation loss: 0.8597
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.75      0.30      0.43        20
#            2       0.80      0.26      0.39        78
#            3       0.55      1.00      0.71        80
#
#     accuracy                           0.59       180
#    macro avg       0.53      0.39      0.38       180
# weighted avg       0.68      0.59      0.53       180
#
# Step: 240    	 Train loss: 0.1400 	 Validation loss: 1.0015
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.73      0.40      0.52        20
#            2       0.87      0.17      0.28        78
#            3       0.53      1.00      0.69        80
#
#     accuracy                           0.57       180
#    macro avg       0.61      0.52      0.47       180
# weighted avg       0.70      0.57      0.49       180
#
# Step: 480    	 Train loss: 0.1088 	 Validation loss: 0.8940
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.64      0.45      0.53        20
#            2       0.90      0.23      0.37        78
#            3       0.56      0.99      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.57      0.54      0.47       180
# weighted avg       0.71      0.59      0.54       180
#
# Epoch: 9     	 Test  loss: 0.8441
#               precision    recall  f1-score   support
#
#            0       0.20      1.00      0.33         2
#            1       0.64      0.35      0.45        20
#            2       0.76      0.21      0.32        78
#            3       0.55      0.95      0.70        80
#
#     accuracy                           0.56       180
#    macro avg       0.54      0.63      0.45       180
# weighted avg       0.65      0.56      0.50       180
#
# Step: 0      	 Train loss: 0.0675 	 Validation loss: 0.8480
#               precision    recall  f1-score   support
#
#            0       0.22      1.00      0.36         2
#            1       0.64      0.35      0.45        20
#            2       0.77      0.22      0.34        78
#            3       0.55      0.95      0.70        80
#
#     accuracy                           0.57       180
#    macro avg       0.55      0.63      0.46       180
# weighted avg       0.65      0.57      0.51       180
#
# Step: 240    	 Train loss: 0.0958 	 Validation loss: 0.9633
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         2
#            1       0.86      0.30      0.44        20
#            2       0.78      0.23      0.36        78
#            3       0.56      1.00      0.71        80
#
#     accuracy                           0.59       180
#    macro avg       0.63      0.63      0.50       180
# weighted avg       0.68      0.59      0.53       180
#
# Step: 480    	 Train loss: 0.0963 	 Validation loss: 0.9544
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.62      0.40      0.48        20
#            2       0.78      0.23      0.36        78
#            3       0.56      0.99      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.55      0.53      0.47       180
# weighted avg       0.66      0.59      0.53       180
#
# Epoch: 10    	 Test  loss: 0.9953
#               precision    recall  f1-score   support
#
#            0       0.14      0.50      0.22         2
#            1       0.64      0.45      0.53        20
#            2       0.89      0.21      0.33        78
#            3       0.56      0.99      0.71        80
#
#     accuracy                           0.58       180
#    macro avg       0.56      0.54      0.45       180
# weighted avg       0.71      0.58      0.52       180
#
# Step: 0      	 Train loss: 0.0557 	 Validation loss: 0.9985
#               precision    recall  f1-score   support
#
#            0       0.14      0.50      0.22         2
#            1       0.64      0.45      0.53        20
#            2       0.89      0.21      0.33        78
#            3       0.56      0.99      0.71        80
#
#     accuracy                           0.58       180
#    macro avg       0.56      0.54      0.45       180
# weighted avg       0.71      0.58      0.52       180
#
# Step: 240    	 Train loss: 0.0715 	 Validation loss: 1.0621
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.86      0.30      0.44        20
#            2       0.82      0.23      0.36        78
#            3       0.55      1.00      0.71        80
#
#     accuracy                           0.58       180
#    macro avg       0.60      0.51      0.44       180
# weighted avg       0.70      0.58      0.52       180
#
# Step: 480    	 Train loss: 0.0797 	 Validation loss: 0.8690
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40         2
#            1       0.62      0.50      0.56        20
#            2       0.79      0.24      0.37        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.56      0.67      0.51       180
# weighted avg       0.67      0.59      0.55       180
#
# Epoch: 11    	 Test  loss: 0.9559
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.60      0.45      0.51        20
#            2       0.85      0.22      0.35        78
#            3       0.57      1.00      0.73        80
#
#     accuracy                           0.59       180
#    macro avg       0.56      0.54      0.47       180
# weighted avg       0.69      0.59      0.53       180
#
# Step: 0      	 Train loss: 0.0389 	 Validation loss: 0.9271
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.60      0.45      0.51        20
#            2       0.82      0.23      0.36        78
#            3       0.57      0.99      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.55      0.54      0.47       180
# weighted avg       0.68      0.59      0.54       180
#
# Step: 240    	 Train loss: 0.0592 	 Validation loss: 1.1307
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40         2
#            1       0.64      0.45      0.53        20
#            2       0.93      0.18      0.30        78
#            3       0.56      1.00      0.72        80
#
#     accuracy                           0.58       180
#    macro avg       0.60      0.66      0.49       180
# weighted avg       0.73      0.58      0.51       180
#
# Step: 480    	 Train loss: 0.0479 	 Validation loss: 1.0010
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.54      0.35      0.42        20
#            2       0.76      0.24      0.37        78
#            3       0.57      0.97      0.72        80
#
#     accuracy                           0.58       180
#    macro avg       0.47      0.39      0.38       180
# weighted avg       0.64      0.58      0.53       180
#
# Epoch: 12    	 Test  loss: 1.0161
#               precision    recall  f1-score   support
#
#            0       0.11      0.50      0.18         2
#            1       0.62      0.40      0.48        20
#            2       0.85      0.22      0.35        78
#            3       0.57      0.97      0.72        80
#
#     accuracy                           0.58       180
#    macro avg       0.54      0.52      0.43       180
# weighted avg       0.69      0.58      0.52       180
#
# Step: 0      	 Train loss: 0.0044 	 Validation loss: 1.0224
#               precision    recall  f1-score   support
#
#            0       0.11      0.50      0.18         2
#            1       0.62      0.40      0.48        20
#            2       0.85      0.22      0.35        78
#            3       0.57      0.97      0.72        80
#
#     accuracy                           0.58       180
#    macro avg       0.54      0.52      0.43       180
# weighted avg       0.69      0.58      0.52       180
#
# Step: 240    	 Train loss: 0.0417 	 Validation loss: 1.0759
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.62      0.40      0.48        20
#            2       0.83      0.24      0.38        78
#            3       0.57      0.99      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.55      0.53      0.46       180
# weighted avg       0.68      0.59      0.54       180
#
# Step: 480    	 Train loss: 0.0546 	 Validation loss: 1.0803
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         2
#            1       0.52      0.55      0.54        20
#            2       0.79      0.19      0.31        78
#            3       0.58      0.97      0.73        80
#
#     accuracy                           0.59       180
#    macro avg       0.56      0.68      0.52       180
# weighted avg       0.66      0.59      0.52       180
#
# Epoch: 13    	 Test  loss: 1.0427
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.73      0.40      0.52        20
#            2       0.79      0.29      0.43        78
#            3       0.58      0.97      0.73        80
#
#     accuracy                           0.61       180
#    macro avg       0.52      0.42      0.42       180
# weighted avg       0.68      0.61      0.57       180
#
# Step: 0      	 Train loss: 0.0272 	 Validation loss: 1.0267
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.73      0.40      0.52        20
#            2       0.79      0.29      0.43        78
#            3       0.58      0.97      0.73        80
#
#     accuracy                           0.61       180
#    macro avg       0.52      0.42      0.42       180
# weighted avg       0.68      0.61      0.57       180
#
# Step: 240    	 Train loss: 0.0336 	 Validation loss: 1.0733
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.55      0.55      0.55        20
#            2       0.75      0.23      0.35        78
#            3       0.57      0.95      0.71        80
#
#     accuracy                           0.58       180
#    macro avg       0.47      0.43      0.40       180
# weighted avg       0.64      0.58      0.53       180
#
# Step: 480    	 Train loss: 0.0326 	 Validation loss: 1.1615
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.77      0.50      0.61        20
#            2       0.86      0.24      0.38        78
#            3       0.56      0.97      0.71        80
#
#     accuracy                           0.60       180
#    macro avg       0.59      0.55      0.49       180
# weighted avg       0.71      0.60      0.55       180
#
# Epoch: 14    	 Test  loss: 1.1158
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.48      0.55      0.51        20
#            2       0.75      0.19      0.31        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.57       180
#    macro avg       0.45      0.43      0.38       180
# weighted avg       0.63      0.57      0.51       180
#
# Step: 0      	 Train loss: 0.0009 	 Validation loss: 1.1162
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.48      0.55      0.51        20
#            2       0.75      0.19      0.31        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.57       180
#    macro avg       0.45      0.43      0.38       180
# weighted avg       0.63      0.57      0.51       180
#
# Step: 240    	 Train loss: 0.0160 	 Validation loss: 1.1064
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.73      0.55      0.63        20
#            2       0.81      0.28      0.42        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.61       180
#    macro avg       0.53      0.45      0.44       180
# weighted avg       0.69      0.61      0.57       180
#
# Step: 480    	 Train loss: 0.0213 	 Validation loss: 1.1464
#               precision    recall  f1-score   support
#
#            0       0.12      0.50      0.20         2
#            1       0.86      0.30      0.44        20
#            2       0.76      0.28      0.41        78
#            3       0.57      0.96      0.71        80
#
#     accuracy                           0.59       180
#    macro avg       0.58      0.51      0.44       180
# weighted avg       0.68      0.59      0.55       180
#
# Epoch: 15    	 Test  loss: 1.2380
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.59      0.50      0.54        20
#            2       0.80      0.21      0.33        78
#            3       0.57      0.99      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.55      0.55      0.48       180
# weighted avg       0.67      0.59      0.53       180
#
# Step: 0      	 Train loss: 0.0012 	 Validation loss: 1.2392
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.59      0.50      0.54        20
#            2       0.80      0.21      0.33        78
#            3       0.57      0.99      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.55      0.55      0.48       180
# weighted avg       0.67      0.59      0.53       180
#
# Step: 240    	 Train loss: 0.0413 	 Validation loss: 1.1994
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.75      0.30      0.43        20
#            2       0.78      0.27      0.40        78
#            3       0.56      0.99      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.52      0.39      0.39       180
# weighted avg       0.67      0.59      0.54       180
#
# Step: 480    	 Train loss: 0.0190 	 Validation loss: 1.1858
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.56      0.50      0.53        20
#            2       0.83      0.24      0.38        78
#            3       0.58      0.96      0.72        80
#
#     accuracy                           0.59       180
#    macro avg       0.53      0.55      0.47       180
# weighted avg       0.68      0.59      0.55       180
#
# Epoch: 16    	 Test  loss: 1.1546
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.73      0.40      0.52        20
#            2       0.76      0.28      0.41        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.60       180
#    macro avg       0.56      0.54      0.47       180
# weighted avg       0.67      0.60      0.56       180
#
# Step: 0      	 Train loss: 0.0071 	 Validation loss: 1.1526
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.73      0.40      0.52        20
#            2       0.76      0.28      0.41        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.60       180
#    macro avg       0.56      0.54      0.47       180
# weighted avg       0.67      0.60      0.56       180
#
# Step: 240    	 Train loss: 0.0137 	 Validation loss: 1.3159
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.69      0.45      0.55        20
#            2       0.83      0.24      0.38        78
#            3       0.57      0.99      0.72        80
#
#     accuracy                           0.60       180
#    macro avg       0.57      0.55      0.48       180
# weighted avg       0.69      0.60      0.55       180
#
# Step: 480    	 Train loss: 0.0284 	 Validation loss: 1.1266
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.73      0.40      0.52        20
#            2       0.77      0.29      0.43        78
#            3       0.58      0.96      0.72        80
#
#     accuracy                           0.61       180
#    macro avg       0.56      0.54      0.48       180
# weighted avg       0.67      0.61      0.57       180
#
# Epoch: 17    	 Test  loss: 1.0976
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.43      0.60      0.50        20
#            2       0.71      0.19      0.30        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.57       180
#    macro avg       0.50      0.56      0.47       180
# weighted avg       0.62      0.57      0.51       180
#
# Step: 0      	 Train loss: 0.0059 	 Validation loss: 1.1058
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.44      0.60      0.51        20
#            2       0.71      0.19      0.30        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.57       180
#    macro avg       0.50      0.56      0.47       180
# weighted avg       0.62      0.57      0.51       180
#
# Step: 240    	 Train loss: 0.0135 	 Validation loss: 1.2143
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.67      0.40      0.50        20
#            2       0.79      0.28      0.42        78
#            3       0.58      0.97      0.73        80
#
#     accuracy                           0.61       180
#    macro avg       0.56      0.54      0.48       180
# weighted avg       0.67      0.61      0.56       180
#
# Step: 480    	 Train loss: 0.0143 	 Validation loss: 1.3892
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.50      0.59        20
#            2       0.77      0.22      0.34        78
#            3       0.56      0.99      0.71        80
#
#     accuracy                           0.59       180
#    macro avg       0.60      0.55      0.51       180
# weighted avg       0.67      0.59      0.53       180
#
# Epoch: 18    	 Test  loss: 1.2276
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.80      0.40      0.53        20
#            2       0.77      0.29      0.43        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.61       180
#    macro avg       0.58      0.54      0.49       180
# weighted avg       0.68      0.61      0.57       180
#
# Step: 0      	 Train loss: 0.0386 	 Validation loss: 1.2440
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.78      0.35      0.48        20
#            2       0.77      0.29      0.43        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.60       180
#    macro avg       0.57      0.53      0.47       180
# weighted avg       0.67      0.60      0.56       180
#
# Step: 240    	 Train loss: 0.0133 	 Validation loss: 1.2341
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.62      0.40      0.48        20
#            2       0.79      0.28      0.42        78
#            3       0.58      0.96      0.72        80
#
#     accuracy                           0.60       180
#    macro avg       0.54      0.54      0.47       180
# weighted avg       0.67      0.60      0.56       180
#
# Step: 480    	 Train loss: 0.0098 	 Validation loss: 1.2624
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.64      0.45      0.53        20
#            2       0.78      0.27      0.40        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.60       180
#    macro avg       0.55      0.55      0.48       180
# weighted avg       0.67      0.60      0.56       180
#
# Epoch: 19    	 Test  loss: 1.2256
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.70      0.35      0.47        20
#            2       0.78      0.32      0.45        78
#            3       0.58      0.96      0.72        80
#
#     accuracy                           0.61       180
#    macro avg       0.52      0.41      0.41       180
# weighted avg       0.67      0.61      0.57       180
#
# Step: 0      	 Train loss: 0.0004 	 Validation loss: 1.2266
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.70      0.35      0.47        20
#            2       0.78      0.32      0.45        78
#            3       0.58      0.96      0.72        80
#
#     accuracy                           0.61       180
#    macro avg       0.52      0.41      0.41       180
# weighted avg       0.67      0.61      0.57       180
#
# Step: 240    	 Train loss: 0.0110 	 Validation loss: 1.2406
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.61      0.55      0.58        20
#            2       0.81      0.27      0.40        78
#            3       0.58      0.96      0.73        80
#
#     accuracy                           0.61       180
#    macro avg       0.56      0.57      0.51       180
# weighted avg       0.68      0.61      0.57       180
#
# Step: 480    	 Train loss: 0.0110 	 Validation loss: 1.2095
#               precision    recall  f1-score   support
#
#            0       0.18      1.00      0.31         2
#            1       0.83      0.25      0.38        20
#            2       0.79      0.33      0.47        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.61       180
#    macro avg       0.60      0.63      0.47       180
# weighted avg       0.70      0.61      0.57       180
#
# Epoch: 20    	 Test  loss: 1.2022
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.79      0.55      0.65        20
#            2       0.84      0.33      0.48        78
#            3       0.59      0.96      0.73        80
#
#     accuracy                           0.64       180
#    macro avg       0.62      0.59      0.55       180
# weighted avg       0.71      0.64      0.61       180
#
# Step: 0      	 Train loss: 0.0138 	 Validation loss: 1.2018
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.73      0.55      0.63        20
#            2       0.83      0.32      0.46        78
#            3       0.59      0.96      0.73        80
#
#     accuracy                           0.63       180
#    macro avg       0.60      0.58      0.54       180
# weighted avg       0.71      0.63      0.60       180
#
# Step: 240    	 Train loss: 0.0170 	 Validation loss: 1.4831
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.78      0.35      0.48        20
#            2       0.80      0.26      0.39        78
#            3       0.56      0.99      0.71        80
#
#     accuracy                           0.59       180
#    macro avg       0.53      0.40      0.40       180
# weighted avg       0.68      0.59      0.54       180
#
# Step: 480    	 Train loss: 0.0120 	 Validation loss: 1.1300
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.64      0.45      0.53        20
#            2       0.74      0.29      0.42        78
#            3       0.58      0.94      0.72        80
#
#     accuracy                           0.60       180
#    macro avg       0.53      0.55      0.48       180
# weighted avg       0.65      0.60      0.56       180
#
# Epoch: 21    	 Test  loss: 1.3305
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.82      0.45      0.58        20
#            2       0.77      0.31      0.44        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.60      0.56      0.52       180
# weighted avg       0.68      0.62      0.58       180
#
# Step: 0      	 Train loss: 0.0013 	 Validation loss: 1.3285
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.82      0.45      0.58        20
#            2       0.77      0.31      0.44        78
#            3       0.57      0.96      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.60      0.56      0.52       180
# weighted avg       0.68      0.62      0.58       180
#
# Step: 240    	 Train loss: 0.0062 	 Validation loss: 1.2013
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.71      0.50      0.59        20
#            2       0.78      0.32      0.45        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.58      0.57      0.52       180
# weighted avg       0.68      0.62      0.59       180
#
# Step: 480    	 Train loss: 0.0104 	 Validation loss: 1.2756
#               precision    recall  f1-score   support
#
#            0       0.14      0.50      0.22         2
#            1       0.73      0.40      0.52        20
#            2       0.80      0.31      0.44        78
#            3       0.58      0.96      0.73        80
#
#     accuracy                           0.61       180
#    macro avg       0.56      0.54      0.48       180
# weighted avg       0.69      0.61      0.58       180
#
# Epoch: 22    	 Test  loss: 1.2103
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.65      0.55      0.59        20
#            2       0.79      0.29      0.43        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.57      0.57      0.52       180
# weighted avg       0.68      0.62      0.58       180
#
# Step: 0      	 Train loss: 0.0001 	 Validation loss: 1.2086
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.65      0.55      0.59        20
#            2       0.79      0.29      0.43        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.57      0.57      0.52       180
# weighted avg       0.68      0.62      0.58       180
#
# Step: 240    	 Train loss: 0.0067 	 Validation loss: 1.0920
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.61      0.55      0.58        20
#            2       0.76      0.32      0.45        78
#            3       0.59      0.93      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.55      0.57      0.52       180
# weighted avg       0.66      0.62      0.58       180
#
# Step: 480    	 Train loss: 0.0074 	 Validation loss: 1.1107
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.79      0.55      0.65        20
#            2       0.78      0.36      0.49        78
#            3       0.59      0.93      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.59      0.58      0.54       180
# weighted avg       0.69      0.63      0.61       180
#
# Epoch: 23    	 Test  loss: 1.0955
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.61      0.55      0.58        20
#            2       0.74      0.32      0.45        78
#            3       0.60      0.93      0.73        80
#
#     accuracy                           0.62       180
#    macro avg       0.55      0.57      0.52       180
# weighted avg       0.65      0.62      0.58       180
#
# Step: 0      	 Train loss: 0.0015 	 Validation loss: 1.1015
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.61      0.55      0.58        20
#            2       0.74      0.32      0.45        78
#            3       0.60      0.93      0.73        80
#
#     accuracy                           0.62       180
#    macro avg       0.55      0.57      0.52       180
# weighted avg       0.65      0.62      0.58       180
#
# Step: 240    	 Train loss: 0.0067 	 Validation loss: 1.2385
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.77      0.31      0.44        78
#            3       0.58      0.94      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.60      0.59      0.55       180
# weighted avg       0.68      0.62      0.59       180
#
# Step: 480    	 Train loss: 0.0079 	 Validation loss: 1.2663
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.69      0.55      0.61        20
#            2       0.77      0.31      0.44        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.58      0.54       180
# weighted avg       0.68      0.62      0.58       180
#
# Epoch: 24    	 Test  loss: 1.3115
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.67      0.50      0.57        20
#            2       0.77      0.31      0.44        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.57      0.56      0.52       180
# weighted avg       0.67      0.62      0.58       180
#
# Step: 0      	 Train loss: 0.0053 	 Validation loss: 1.3101
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.67      0.50      0.57        20
#            2       0.77      0.31      0.44        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.57      0.56      0.52       180
# weighted avg       0.67      0.62      0.58       180
#
# Step: 240    	 Train loss: 0.0056 	 Validation loss: 1.3268
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.44      0.60      0.51        20
#            2       0.73      0.21      0.32        78
#            3       0.58      0.93      0.71        80
#
#     accuracy                           0.57       180
#    macro avg       0.50      0.56      0.47       180
# weighted avg       0.63      0.57      0.52       180
#
# Step: 480    	 Train loss: 0.0079 	 Validation loss: 1.2641
# ...
#            1       0.71      0.60      0.65        20
#            2       0.77      0.31      0.44        78
#            3       0.59      0.95      0.73        80
#
#     accuracy                           0.63       180
#    macro avg       0.60      0.59      0.55       180
# weighted avg       0.68      0.63      0.59       180
#
# Step: 0      	 Train loss: 0.0001 	 Validation loss: 1.2870
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.77      0.31      0.44        78
#            3       0.59      0.95      0.73        80
#
#     accuracy                           0.63       180
#    macro avg       0.60      0.59      0.55       180
# weighted avg       0.68      0.63      0.59       180
#
# Step: 240    	 Train loss: 0.0030 	 Validation loss: 1.2541
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.73      0.31      0.43        78
#            3       0.58      0.93      0.71        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.58      0.55       180
# weighted avg       0.66      0.62      0.58       180
#
# Step: 480    	 Train loss: 0.0039 	 Validation loss: 1.2776
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.80      0.31      0.44        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.61      0.59      0.55       180
# weighted avg       0.69      0.63      0.59       180
#
# Epoch: 28    	 Test  loss: 1.2055
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.74      0.32      0.45        78
#            3       0.59      0.93      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.59      0.55       180
# weighted avg       0.66      0.62      0.59       180
#
# Step: 0      	 Train loss: 0.0295 	 Validation loss: 1.2063
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.74      0.32      0.45        78
#            3       0.59      0.93      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.59      0.55       180
# weighted avg       0.66      0.62      0.59       180
#
# Step: 240    	 Train loss: 0.0033 	 Validation loss: 1.3301
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.79      0.29      0.43        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.60      0.59      0.55       180
# weighted avg       0.68      0.62      0.58       180
#
# Step: 480    	 Train loss: 0.0056 	 Validation loss: 1.1771
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.65      0.55      0.59        20
#            2       0.74      0.33      0.46        78
#            3       0.60      0.93      0.73        80
#
#     accuracy                           0.62       180
#    macro avg       0.56      0.58      0.53       180
# weighted avg       0.66      0.62      0.59       180
#
# Epoch: 29    	 Test  loss: 1.3130
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.82      0.45      0.58        20
#            2       0.81      0.32      0.46        78
#            3       0.58      0.96      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.60      0.56      0.51       180
# weighted avg       0.70      0.62      0.59       180
#
# Step: 0      	 Train loss: 0.0143 	 Validation loss: 1.3104
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.82      0.45      0.58        20
#            2       0.78      0.32      0.45        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.56      0.51       180
# weighted avg       0.69      0.62      0.58       180
#
# Step: 240    	 Train loss: 0.0025 	 Validation loss: 1.2334
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.69      0.55      0.61        20
#            2       0.78      0.32      0.45        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.58      0.58      0.53       180
# weighted avg       0.68      0.62      0.59       180
#
# Step: 480    	 Train loss: 0.0045 	 Validation loss: 1.2840
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.79      0.55      0.65        20
#            2       0.79      0.35      0.48        78
#            3       0.59      0.95      0.73        80
#
#     accuracy                           0.64       180
#    macro avg       0.63      0.59      0.56       180
# weighted avg       0.70      0.64      0.61       180
#
# Epoch: 30    	 Test  loss: 1.2795
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.83      0.50      0.62        20
#            2       0.80      0.36      0.50        78
#            3       0.59      0.95      0.73        80
#
#     accuracy                           0.64       180
#    macro avg       0.62      0.58      0.55       180
# weighted avg       0.70      0.64      0.61       180
#
# Step: 0      	 Train loss: 0.0009 	 Validation loss: 1.2780
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.83      0.50      0.62        20
#            2       0.80      0.36      0.50        78
#            3       0.59      0.95      0.73        80
#
#     accuracy                           0.64       180
#    macro avg       0.62      0.58      0.55       180
# weighted avg       0.70      0.64      0.61       180
#
# Step: 240    	 Train loss: 0.0020 	 Validation loss: 1.2448
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.73      0.55      0.63        20
#            2       0.79      0.33      0.47        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.59      0.58      0.54       180
# weighted avg       0.69      0.63      0.60       180
#
# Step: 480    	 Train loss: 0.0040 	 Validation loss: 1.3310
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.83      0.50      0.62        20
#            2       0.79      0.35      0.48        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.62      0.57      0.54       180
# weighted avg       0.70      0.63      0.60       180
#
# Epoch: 31    	 Test  loss: 1.2231
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.79      0.55      0.65        20
#            2       0.80      0.36      0.50        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.64       180
#    macro avg       0.61      0.59      0.55       180
# weighted avg       0.70      0.64      0.61       180
#
# Step: 0      	 Train loss: 0.0051 	 Validation loss: 1.2184
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.79      0.55      0.65        20
#            2       0.80      0.36      0.50        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.64       180
#    macro avg       0.61      0.59      0.55       180
# weighted avg       0.70      0.64      0.61       180
#
# Step: 240    	 Train loss: 0.0077 	 Validation loss: 1.1794
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.44      0.55      0.49        20
#            2       0.78      0.32      0.45        78
#            3       0.63      0.93      0.75        80
#
#     accuracy                           0.62       180
#    macro avg       0.51      0.57      0.49       180
# weighted avg       0.67      0.62      0.59       180
#
# Step: 480    	 Train loss: 0.0040 	 Validation loss: 1.2055
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.60      0.60      0.60        20
#            2       0.76      0.32      0.45        78
#            3       0.60      0.93      0.73        80
#
#     accuracy                           0.62       180
#    macro avg       0.57      0.59      0.54       180
# weighted avg       0.66      0.62      0.59       180
#
# Epoch: 32    	 Test  loss: 1.2694
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.63      0.60      0.62        20
#            2       0.77      0.29      0.43        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.58      0.58      0.54       180
# weighted avg       0.67      0.62      0.58       180
#
# Step: 0      	 Train loss: 0.0001 	 Validation loss: 1.2693
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.63      0.60      0.62        20
#            2       0.77      0.29      0.43        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.58      0.58      0.54       180
# weighted avg       0.67      0.62      0.58       180
#
# Step: 240    	 Train loss: 0.0052 	 Validation loss: 1.3101
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.75      0.60      0.67        20
#            2       0.81      0.32      0.46        78
#            3       0.58      0.95      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.62      0.59      0.56       180
# weighted avg       0.70      0.63      0.60       180
#
# Step: 480    	 Train loss: 0.0020 	 Validation loss: 1.2755
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.78      0.32      0.45        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.60      0.59      0.56       180
# weighted avg       0.68      0.63      0.59       180
#
# Epoch: 33    	 Test  loss: 1.2688
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.67      0.60      0.63        20
#            2       0.77      0.31      0.44        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.59      0.55       180
# weighted avg       0.67      0.62      0.59       180
#
# Step: 0      	 Train loss: 0.0034 	 Validation loss: 1.2692
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.67      0.60      0.63        20
#            2       0.77      0.31      0.44        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.59      0.55       180
# weighted avg       0.67      0.62      0.59       180
#
# Step: 240    	 Train loss: 0.0022 	 Validation loss: 1.2844
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.75      0.60      0.67        20
#            2       0.79      0.33      0.47        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.61      0.59      0.56       180
# weighted avg       0.69      0.63      0.60       180
#
# Step: 480    	 Train loss: 0.0028 	 Validation loss: 1.2712
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.78      0.32      0.45        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.60      0.59      0.56       180
# weighted avg       0.68      0.63      0.59       180
#
# Epoch: 34    	 Test  loss: 1.3037
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.75      0.60      0.67        20
#            2       0.81      0.33      0.47        78
#            3       0.59      0.95      0.73        80
#
#     accuracy                           0.64       180
#    macro avg       0.62      0.60      0.57       180
# weighted avg       0.70      0.64      0.61       180
#
# Step: 0      	 Train loss: 0.0007 	 Validation loss: 1.3037
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.75      0.60      0.67        20
#            2       0.81      0.33      0.47        78
#            3       0.59      0.95      0.73        80
#
#     accuracy                           0.64       180
#    macro avg       0.62      0.60      0.57       180
# weighted avg       0.70      0.64      0.61       180
#
# Step: 240    	 Train loss: 0.0025 	 Validation loss: 1.2513
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.78      0.32      0.45        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.60      0.59      0.56       180
# weighted avg       0.68      0.63      0.59       180
#
# Step: 480    	 Train loss: 0.0032 	 Validation loss: 1.2586
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.67      0.60      0.63        20
#            2       0.77      0.31      0.44        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.62       180
#    macro avg       0.59      0.59      0.55       180
# weighted avg       0.67      0.62      0.59       180
#
# Epoch: 35    	 Test  loss: 1.2645
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.71      0.60      0.65        20
#            2       0.78      0.32      0.45        78
#            3       0.59      0.94      0.72        80
#
#     accuracy                           0.63       180
#    macro avg       0.60      0.59      0.56       180
# weighted avg       0.68      0.63      0.59       180
#
# Log file closed.
